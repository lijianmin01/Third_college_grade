# %%
import pandas as pd
print(pd.show_versions())
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.4.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 0.25.0
# numpy            : 1.16.2
# pytz             : 2019.1
# dateutil         : 2.8.0
# pip              : 20.0.2
# setuptools       : 41.4.0
# Cython           : 0.29.13
# pytest           : 5.2.1
# hypothesis       : None
# sphinx           : 2.1.2
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.1
# lxml.etree       : 4.4.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10.1
# IPython          : 7.7.0
# pandas_datareader: None
# bs4              : 4.8.0
# bottleneck       : 1.2.1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.Series([[1,2,3],[4,5,6]])
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# dtype: object

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(['a',1,2,3],index=['Lily','lucy','Lee','Lucky'])
# Out:
# Lily     a
# lucy     1
# Lee      2
# Lucky    3
# dtype: object

# %%
# ?pd.Series

# %%
data = {'a':1,'b':2,'c':3}
pd.Series(data)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(data,index=['a','b','c'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s = pd.Series(data,index=['a','b','c','d'])
s
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# dtype: float64

# %%
s['a']
# Out:
# 1.0

# %%
s[-2:]
# Out:
# c    3.0
# d    NaN
# dtype: float64

# %%
s + s
# Out:
# a    2.0
# b    4.0
# c    6.0
# d    NaN
# dtype: float64

# %%
(s+s).mean()
# Out:
# 4.0

# %%
print(s)
s[1:]+s[:-1]
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# dtype: float64
# a    NaN
# b    4.0
# c    6.0
# d    NaN
# dtype: float64

# %%
pd.DataFrame([[1,2,30],[4,8,20]])
# Out:
#    0  1   2
# 0  1  2  30
# 1  4  8  20

# %%
pd.DataFrame([[1,2,30],[4,8,20]],index=['liming','zhangjie'],columns=['A','B','C'])
# Out:
#           A  B   C
# liming    1  2  30
# zhangjie  4  8  20

# %%
df = data = {'one':pd.Series([1,2,3],index=['a','b','c']),'two':pd.Series([4,5,6,7],index=['a1','b','c','d'])}

pd.DataFrame(data)
# Out:
#     one  two
# a   1.0  NaN
# a1  NaN  4.0
# b   2.0  5.0
# c   3.0  6.0
# d   NaN  7.0

# %%
data = np.arange(25).reshape(5,5)
pd.DataFrame(data)
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %%
df['one']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# 找一行
df.loc['a1']
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# <ipython-input-51-05aefadf908c> in <module>
#       1 # 找一行
# ----> 2 df.loc['a1']
#
# AttributeError: 'dict' object has no attribute 'loc'

# %%
data = {'one':pd.Series([1,2,3],index=['a','b','c']),'two':pd.Series([4,5,6,7],index=['a1','b','c','d'])}

df =pd.DataFrame(data)

# %%
df.iloc[0]
# Out:
# one    1.0
# two    NaN
# Name: a, dtype: float64

# %%
df[:1]
# Out:
#    one  two
# a  1.0  NaN

# %%
df['one']
# Out:
# a     1.0
# a1    NaN
# b     2.0
# c     3.0
# d     NaN
# Name: one, dtype: float64

# %%
df['three']=pd.Series([1,2,3],index=['a','b','c'])
df
# Out:
#     one  two  three
# a   1.0  NaN    1.0
# a1  NaN  4.0    NaN
# b   2.0  5.0    2.0
# c   3.0  6.0    3.0
# d   NaN  7.0    NaN

# %%
df['four']=df['one']+df['three']
df
# Out:
#     one  two  three  four
# a   1.0  NaN    1.0   2.0
# a1  NaN  4.0    NaN   NaN
# b   2.0  5.0    2.0   4.0
# c   3.0  6.0    3.0   6.0
# d   NaN  7.0    NaN   NaN

# %%
df.describe()
# Out:
#        one       two  three  four
# count  3.0  4.000000    3.0   3.0
# mean   2.0  5.500000    2.0   4.0
# std    1.0  1.290994    1.0   2.0
# min    1.0  4.000000    1.0   2.0
# 25%    1.5  4.750000    1.5   3.0
# 50%    2.0  5.500000    2.0   4.0
# 75%    2.5  6.250000    2.5   5.0
# max    3.0  7.000000    3.0   6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a to d
# Data columns (total 4 columns):
# one      3 non-null float64
# two      4 non-null float64
# three    3 non-null float64
# four     3 non-null float64
# dtypes: float64(4)
# memory usage: 360.0+ bytes

# %%
# 读文件
f = pd.read_csv('titanic.csv')
f
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
f.head()  # 默认前五条信息
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
f.to_excel('titanic.xls',sheet_name='passengers',index=False)

# %%
t = pd.read_excel('titanic.xls')

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
t[['Age','Sex']][:5]
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
t[t['Age']>35]['Age'].shape
# Out:
# (217,)

# %%
t['Age']>35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
t[t['Age'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.loc[t['Age']>35,'Name'][:10]
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 30                             Uruchurtu, Don. Manuel E
# 33                                Wheadon, Mr. Edward H
# 35                       Holverson, Mr. Alexander Oskar
# 40       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Name: Name, dtype: object

# %%
t.iloc[9:25,1:5]
# Out:
#     Survived  Pclass                                               Name  \
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 12         0       3                     Saundercock, Mr. William Henry
# 13         0       3                        Andersson, Mr. Anders Johan
# 14         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         0       3                               Rice, Master. Eugene
# 17         1       2                       Williams, Mr. Charles Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19         1       3                            Masselmani, Mrs. Fatima
# 20         0       2                               Fynney, Mr. Joseph J
# ...

# %%
air_quality = pd.read_csv('air_quality_no2.csv',index_col=0,parse_dates=True)

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 4 columns):
# datetime           1035 non-null object
# station_antwerp    95 non-null float64
# station_paris      1004 non-null float64
# station_london     969 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 32.5+ KB

# %%
air_quality.plot()

# %%
air_quality['station_paris'].plot()

# %%
air_quality.plot.scatter(x='station_london',y='station_paris')

# %%
air_quality.plot.area(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F987E2DCC8>,
# ...
#       dtype=object)

# %%
t[['Age','Fare']].describe().loc[['min','max','mean']]
# Out:
#             Age        Fare
# min    0.420000    0.000000
# max   80.000000  512.329200
# mean  29.699118   32.204208

# %%
t.agg({'Age':['min','max','mean'],
      'Name':['min','max','mean']})
# Out:
#             Age                         Name
# max   80.000000  van Melkebeke, Mr. Philemon
# mean  29.699118                          NaN
# min    0.420000          Abbing, Mr. Anthony

# %%
t.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
t[['Age','Sex']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %% [markdown]
# ### 1、统计相关的问题
# ### 2、重塑表格布局
# ### 3、合并来自多个表的数据
# ### 4、处理时间序列
# ### 5、处理文本数据

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.groupby(['Sex','Pclass'])['Fare'].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic.groupby(['Sex','Pclass'])['Fare'].count()
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# Name: Fare, dtype: int64

# %%
titanic.groupby(['Pclass'])['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ## 重塑表格布局

# %%
# 导入空气质量数据集
air_quality = pd.read('air_quality_long.csv')
